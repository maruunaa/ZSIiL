# %%
# !pip -q install google-generativeai

from getpass import getpass
import os
import google.generativeai as genai

os.environ["GEMINI_API_KEY"] = getpass("Введи Gemini API key: AIzaSyBqhpeCOIO-wsPm05WZnNN86iauRoCnPu0")
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

system_prompt = """
You are a helpful assistant.
Always reply in Ukrainian.
Be clear and concise.
"""

model = genai.GenerativeModel(
    "gemini-2.5-flash",
    system_instruction=system_prompt
)

chat = model.start_chat(history=[])

print("Напиши 'exit' щоб вийти")

while True:
    user = input("Ти: ")
    if user.lower() == "exit":
        break

    response = chat.send_message(user)
    print("Бот:", response.text)
    print()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Введи Gemini API key: AIzaSyBqhpeCOIO-wsPm05WZnNN86iauRoCnPu0··········
# Напиши 'exit' щоб вийти
# Ти: Привіт, мені сумно
# Бот: Привіт. Мені шкода чути, що тобі сумно. Це нормально відчувати смуток.
#
# Я тут, якщо тобі захочеться про щось поговорити, чи просто висловитися.
#
# Ти: Яка погода сьогодні у Львові?
# Бот: Зараз у Львові **+16°C**, переважно хмарно, але без опадів. Вітер легкий.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16816/3722071884.py in <cell line: 0>()
#      24
#      25 while True:
# ---> 26     user = input("Ти: ")
#      27     if user.lower() == "exit":
#      28         break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
